-- %%
CREATE TABLE Employeee (
emp_id INT,
emp_name VARCHAR(50),
department VARCHAR(50),
salary INT,
experience INT,
performance_rating CHAR(1)
);

-- %%
INSERT INTO Employeee (emp_id, emp_name, department, salary, experience, performance_rating)
VALUES
(1, 'Karthik', 'Engineering', 95000, 9, 'A'),
(2, 'Prathik', 'HR', 55000, 4, 'B'),
(3, 'Vinay', 'Finance', 78000, 10, 'B'),
(4, 'Vijay', 'Marketing', 48000, 3, 'C'),
(5, 'Anil', 'Engineering', 88000, 6, 'A'),
(6, 'Suresh', 'Finance', 92000, 12, 'A'),
(7, 'Ramesh', 'HR', 46000, 2, 'C'),
(8, 'Mahesh', 'Marketing', 67000, 7, 'B'),
(9, 'Rajesh', 'Engineering', 72000, 5, 'B'),
(10,'Naveen', 'Finance', 61000, 6, 'C'),
(11,'Deepak', 'HR', 83000, 11, 'A'),
(12,'Arjun', 'Engineering', 54000, 3, 'C'),
(13,'Kiran', 'Marketing', 76000, 8, 'A'),
(14,'Rohit', 'Finance', 68000, 4, 'B'),
(15,'Pavan', 'HR', 59000, 5, 'B'),
(16,'Srikanth', 'Engineering', 102000, 14, 'A'),
(17,'Manoj', 'Finance', 47000, 2, 'C'),
(18,'Varun', 'Marketing', 52000, 6, 'B'),
(19,'Ashok', 'HR', 74000, 9, 'A'),
(20,'Sunil', 'Engineering', 66000, 4, 'B'),
(21,'Nikhil', 'Finance', 86000, 7, 'A'),
(22,'Harish', 'Marketing', 45000, 1, 'C'),
(23,'Vamsi', 'Engineering', 79000, 8, 'B'),
(24,'Chaitanya','HR', 91000, 13, 'A'),
(25,'Lokesh', 'Finance', 58000, 5, 'B');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>25</td><td>25</td></tr></tbody></table></div>

-- %% [markdown]
-- **Problem 1: Salary Hike Based on Experience and Performance**
--
-- Scenario: You want to give a salary hike based on both experience and performance rating. If the employee has:
-- · Experience ≥ 8 and Performance 'A', they get a 20% hike.
-- · Experience ≥ 5 and Performance 'B', they get a 15% hike.
-- · Performance 'C' gets no hike.
-- · For other cases, they get a 10% hike.

-- %%
select *,
case 
when experience >= 8 and performance_rating = 'A' then salary * 1.20 
when experience >= 5 and performance_rating = 'B' then salary * 1.15
when performance_rating = 'C' then salary
else salary * 1.10
end as updated_salary
from Employeee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>department</th><th>salary</th><th>experience</th><th>performance_rating</th><th>updated_salary</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>Engineering</td><td>95000</td><td>9</td><td>A</td><td>114000.00</td></tr><tr><td>2</td><td>Prathik</td><td>HR</td><td>55000</td><td>4</td><td>B</td><td>60500.00</td></tr><tr><td>3</td><td>Vinay</td><td>Finance</td><td>78000</td><td>10</td><td>B</td><td>89700.00</td></tr><tr><td>4</td><td>Vijay</td><td>Marketing</td><td>48000</td><td>3</td><td>C</td><td>48000.00</td></tr><tr><td>5</td><td>Anil</td><td>Engineering</td><td>88000</td><td>6</td><td>A</td><td>96800.00</td></tr><tr><td>6</td><td>Suresh</td><td>Finance</td><td>92000</td><td>12</td><td>A</td><td>110400.00</td></tr><tr><td>7</td><td>Ramesh</td><td>HR</td><td>46000</td><td>2</td><td>C</td><td>46000.00</td></tr><tr><td>8</td><td>Mahesh</td><td>Marketing</td><td>67000</td><td>7</td><td>B</td><td>77050.00</td></tr><tr><td>9</td><td>Rajesh</td><td>Engineering</td><td>72000</td><td>5</td><td>B</td><td>82800.00</td></tr><tr><td>10</td><td>Naveen</td><td>Finance</td><td>61000</td><td>6</td><td>C</td><td>61000.00</td></tr><tr><td>11</td><td>Deepak</td><td>HR</td><td>83000</td><td>11</td><td>A</td><td>99600.00</td></tr><tr><td>12</td><td>Arjun</td><td>Engineering</td><td>54000</td><td>3</td><td>C</td><td>54000.00</td></tr><tr><td>13</td><td>Kiran</td><td>Marketing</td><td>76000</td><td>8</td><td>A</td><td>91200.00</td></tr><tr><td>14</td><td>Rohit</td><td>Finance</td><td>68000</td><td>4</td><td>B</td><td>74800.00</td></tr><tr><td>15</td><td>Pavan</td><td>HR</td><td>59000</td><td>5</td><td>B</td><td>67850.00</td></tr><tr><td>16</td><td>Srikanth</td><td>Engineering</td><td>102000</td><td>14</td><td>A</td><td>122400.00</td></tr><tr><td>17</td><td>Manoj</td><td>Finance</td><td>47000</td><td>2</td><td>C</td><td>47000.00</td></tr><tr><td>18</td><td>Varun</td><td>Marketing</td><td>52000</td><td>6</td><td>B</td><td>59800.00</td></tr><tr><td>19</td><td>Ashok</td><td>HR</td><td>74000</td><td>9</td><td>A</td><td>88800.00</td></tr><tr><td>20</td><td>Sunil</td><td>Engineering</td><td>66000</td><td>4</td><td>B</td><td>72600.00</td></tr><tr><td>21</td><td>Nikhil</td><td>Finance</td><td>86000</td><td>7</td><td>A</td><td>94600.00</td></tr><tr><td>22</td><td>Harish</td><td>Marketing</td><td>45000</td><td>1</td><td>C</td><td>45000.00</td></tr><tr><td>23</td><td>Vamsi</td><td>Engineering</td><td>79000</td><td>8</td><td>B</td><td>90850.00</td></tr><tr><td>24</td><td>Chaitanya</td><td>HR</td><td>91000</td><td>13</td><td>A</td><td>109200.00</td></tr><tr><td>25</td><td>Lokesh</td><td>Finance</td><td>58000</td><td>5</td><td>B</td><td>66700.00</td></tr></tbody></table></div>

-- %% [markdown]
-- **2) Problem 2: Bonus Calculation Based on Department and Performance**
--
-- Scenario: Bonus is calculated based on the department and performance rating:
-- · For Finance department:
-- o If performance is 'A', the bonus is 20% of the salary.
-- o If performance is 'B', the bonus is 15% of the salary.
-- o If performance is 'C', the bonus is 5% of the salary.
-- · For Engineering department:
-- o If performance is 'A', the bonus is 18% of the salary.
-- o If performance is 'B', the bonus is 12% of the salary.
-- o If performance is 'C', the bonus is 3% of the salary.
-- · For other departments, a flat 10% bonus.

-- %%
select *,
case 
when department='Finance' and performance_rating = 'A' then salary * 1.20 
when department='Finance' and performance_rating = 'B' then salary * 1.15
when department='Finance' and performance_rating = 'C' then salary*1.05
when department='Engineering' and performance_rating = 'A' then salary * 1.18 
when department='Engineering' and performance_rating = 'B' then salary * 1.12
when department='Engineering' and performance_rating='C' then salary*1.03
else salary * 1.10
end as updated_salary
from Employeee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th
-- %% [markdown]
-- **Problem 3: Categorizing Employees by Salary Range and Performance**
--
-- Scenario: You want to categorize employees based on salary ranges and their performance:
-- · If salary is greater than 80,000 and performance is 'A', label them as High Performer.
-- · If salary is between 50,000 and 80,000 and performance is 'B', label them as Mid Performer.
-- · If salary is less than 50,000 or performance is 'C', label them as Low Performer.

-- %%
select *,
case 
when salary >= 80000 and performance_rating = 'A' then "High performer"
when salary between 50000 and 80000 and performance_rating = 'B' then "Mid performer"
else "Average"
end as performance_band
from Employeee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>department</th><th>salary</th><th>experience</th><th>performance_rating</th><th>performance_band</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>Engineering</td><td>95000</td><td>9</td><td>A</td><td>High performer</td></tr><tr><td>2</td><td>Prathik</td><td>HR</td><td>55000</td><td>4</td><td>B</td><td>Mid performer</td></tr><tr><td>3</td><td>Vinay</td><td>Finance</td><td>78000</td><td>10</td><td>B</td><td>Mid performer</td></tr><tr><td>4</td><td>Vijay</td><td>Marketing</td><td>48000</td><td>3</td><td>C</td><td>Average</td></tr><tr><td>5</td><td>Anil</td><td>Engineering</td><td>88000</td><td>6</td><td>A</td><td>High performer</td></tr><tr><td>6</td><td>Suresh</td><td>Finance</td><td>92000</td><td>12</td><td>A</td><td>High performer</td></tr><tr><td>7</td><td>Ramesh</td><td>HR</td><td>46000</td><td>2</td><td>C</td><td>Average</td></tr><tr><td>8</td><td>Mahesh</td><td>Marketing</td><td>67000</td><td>7</td><td>B</td><td>Mid performer</td></tr><tr><td>9</td><td>Rajesh</td><td>Engineering</td><td>72000</td><td>5</td><td>B</td><td>Mid performer</td></tr><tr><td>10</td><td>Naveen</td><td>Finance</td><td>61000</td><td>6</td><td>C</td><td>Average</td></tr><tr><td>11</td><td>Deepak</td><td>HR</td><td>83000</td><td>11</td><td>A</td><td>High performer</td></tr><tr><td>12</td><td>Arjun</td><td>Engineering</td><td>54000</td><td>3</td><td>C</td><td>Average</td></tr><tr><td>13</td><td>Kiran</td><td>Marketing</td><td>76000</td><td>8</td><td>A</td><td>Average</td></tr><tr><td>14</td><td>Rohit</td><td>Finance</td><td>68000</td><td>4</td><td>B</td><td>Mid performer</td></tr><tr><td>15</td><td>Pavan</td><td>HR</td><td>59000</td><td>5</td><td>B</td><td>Mid performer</td></tr><tr><td>16</td><td>Srikanth</td><td>Engineering</td><td>102000</td><td>14</td><td>A</td><td>High performer</td></tr><tr><td>17</td><td>Manoj</td><td>Finance</td><td>47000</td><td>2</td><td>C</td><td>Average</td></tr><tr><td>18</td><td>Varun</td><td>Marketing</td><td>52000</td><td>6</td><td>B</td><td>Mid performer</td></tr><tr><td>19</td><td>Ashok</td><td>HR</td><td>74000</td><td>9</td><td>A</td><td>Average</td></tr><tr><td>20</td><td>Sunil</td><td>Engineering</td><td>66000</td><td>4</td><td>B</td><td>Mid performer</td></tr><tr><td>21</td><td>Nikhil</td><td>Finance</td><td>86000</td><td>7</td><td>A</td><td>High performer</td></tr><tr><td>22</td><td>Harish</td><td>Marketing</td><td>45000</td><td>1</td><td>C</td><td>Average</td></tr><tr><td>23</td><td>Vamsi</td><td>Engineering</td><td>79000</td><td>8</td><td>B</td><td>Mid performer</td></tr><tr><td>24</td><td>Chaitanya</td><td>HR</td><td>91000</td><td>13</td><td>A</td><td>High performer</td></tr><tr><td>25</td><td>Lokesh</td><td>Finance</td><td>58000</td><td>5</td><td>B</td><td>Mid performer</td></tr></tbody></table></div>

-- %% [markdown]
-- **Problem 4: Risk Assessment Based on Experience and Department**
--
-- Scenario: You want to assess employee risk based on their experience and department:
-- · For employees in the HR department:
-- o If experience is less than 5 years, they are High Risk.
-- o If experience is more than 5 years, they are Low Risk.
-- · For employees in Engineering or Finance departments:
-- o If experience is more than 8 years, they are Low Risk.
-- o If experience is less than 8 years, they are Medium Risk.
-- · Employees in other departments are automatically labeled Medium Risk.

-- %%
select *,
case 
when department="HR" and experience <5 then "High risk"
when department="HR" and experience >5 then "Low risk"
when department="Engineering" or department="Finanace" and experience >8 then"low risk"
when department="Engineering" or department="Finanace" and experience <8 then"medium risk"
else " Medium risk"
end as Risk
from Employeee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>department</th><th>salary</th><th>experience</th><th>performance_rating</th><th>Risk</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>Engineering</td><td>95000</td><td>9</td><td>A</td><td>low risk</td></tr><tr><td>2</td><td>Prathik</td><td>HR</td><td>55000</td><td>4</td><td>B</td><td>High risk</td></tr><tr><td>3</td><td>Vinay</td><td>Finance</td><td>78000</td><td>10</td><td>B</td><td> Medium risk</td></tr><tr><td>4</td><td>Vijay</td><td>Marketing</td><td>48000</td><td>3</td><td>C</td><td> Medium risk</td></tr><tr><td>5</td><td>Anil</td><td>Engineering</td><td>88000</td><td>6</td><td>A</td><td>low risk</td></tr><tr><td>6</td><td>Suresh</td><td>Finance</td><td>92000</td><td>12</td><td>A</td><td> Medium risk</td></tr><tr><td>7</td><td>Ramesh</td><td>HR</td><td>46000</td><td>2</td><td>C</td><td>High risk</td></tr><tr><td>8</td><td>Mahesh</td><td>Marketing</td><td>67000</td><td>7</td><td>B</td><td> Medium risk</td></tr><tr><td>9</td><td>Rajesh</td><td>Engineering</td><td>72000</td><td>5</td><td>B</td><td>low risk</td></tr><tr><td>10</td><td>Naveen</td><td>Finance</td><td>61000</td><td>6</td><td>C</td><td> Medium risk</td></tr><tr><td>11</td><td>Deepak</td><td>HR</td><td>83000</td><td>11</td><td>A</td><td>Low risk</td></tr><tr><td>12</td><td>Arjun</td><td>Engineering</td><td>54000</td><td>3</td><td>C</td><td>low risk</td></tr><tr><td>13</td><td>Kiran</td><td>Marketing</td><td>76000</td><td>8</td><td>A</td><td> Medium risk</td></tr><tr><td>14</td><td>Rohit</td><td>Finance</td><td>68000</td><td>4</td><td>B</td><td> Medium risk</td></tr><tr><td>15</td><td>Pavan</td><td>HR</td><td>59000</td><td>5</td><td>B</td><td> Medium risk</td></tr><tr><td>16</td><td>Srikanth</td><td>Engineering</td><td>102000</td><td>14</td><td>A</td><td>low risk</td></tr><tr><td>17</td><td>Manoj</td><td>Finance</td><td>47000</td><td>2</td><td>C</td><td> Medium risk</td></tr><tr><td>18</td><td>Varun</td><td>Marketing</td><td>52000</td><td>6</td><td>B</td><td> Medium risk</td></tr><tr><td>19</td><td>Ashok</td><td>HR</td><td>74000</td><td>9</td><td>A</td><td>Low risk</td></tr><tr><td>20</td><td>Sunil</td><td>Engineering</td><td>66000</td><td>4</td><td>B</td><td>low risk</td></tr><tr><td>21</td><td>Nikhil</td><td>Finance</td><td>86000</td><td>7</td><td>A</td><td> Medium risk</td></tr><tr><td>22</td><td>Harish</td><td>Marketing</td><td>45000</td><td>1</td><td>C</td><td> Medium risk</td></tr><tr><td>23</td><td>Vamsi</td><td>Engineering</td><td>79000</td><td>8</td><td>B</td><td>low risk</td></tr><tr><td>24</td><td>Chaitanya</td><td>HR</td><td>91000</td><td>13</td><td>A</td><td>Low risk</td></tr><tr><td>25</td><td>Lokesh</td><td>Finance</td><td>58000</td><td>5</td><td>B</td><td> Medium risk</td></tr></tbody></table></div>

-- %% [markdown]
-- **Nested case and when**
--
-- **Problem 1: Nested CASE for Performance and Salary Hike Based on Multiple Criteria**
--
-- Scenario: You want to determine the salary hike based on performance rating, experience, and current salary. The hike rules are:
-- · If performance is 'A':
-- o For salaries above 80,000, experience above 5 years gets a 25% hike, otherwise 20%.
-- o For salaries between 50,000 and 80,000, the hike is 15%.
-- · If performance is 'B':
-- o For experience above 5 years, the hike is 12%.
-- o Otherwise, it's 10%.
-- · For performance 'C', there is no hike.

-- %%
select *,
case 
  when performance_rating = 'A' then
    case
      when salary > 80000 then
        case
          when experience > 5 then salary * 1.25
          else salary * 1.20
        end
      when salary between 50000 and 80000 then salary * 1.15
      else salary
    end
  when performance_rating = 'B' then
    case
      when experience > 5 then salary * 1.12
      else salary * 1.10
    end
  when performance_rating = 'C' then salary
  else salary
end as updated_salary
from Employeee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>department</th><th>salary</th><th>experience</th><th>performance_rating</th><th>updated_salary</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>Engineering</td><td>95000</td><td>9</td><td>A</td><td>118750.00</td></tr><tr><td>2</td><td>Prathik</td><td>HR</td><td>55000</td><td>4</td><td>B</td><td>60500.00</td></tr><tr><td>3</td><td>Vinay</td><td>Finance</td><td>78000</td><td>10</td><td>B</td><td>87360.00</td></tr><tr><td>4</td><td>Vijay</td><td>Marketing</td><td>48000</td><td>3</td><td>C</td><td>48000.00</td></tr><tr><td>5</td><td>Anil</td><td>Engineering</td><td>88000</td><td>6</td><td>A</td><td>110000.00</td></tr><tr><td>6</td><td>Suresh</td><td>Finance</td><td>92000</td><td>12</td><td>A</td><td>115000.00</td></tr><tr><td>7</td><td>Ramesh</td><td>HR</td><td>46000</td><td>2</td><td>C</td><td>46000.00</td></tr><tr><td>8</td><td>Mahesh</td><td>Marketing</td><td>67000</td><td>7</td><td>B</td><td>75040.00</td></tr><tr><td>9</td><td>Rajesh</td><td>Engineering</td><td>72000</td><td>5</td><td>B</td><td>79200.00</td></tr><tr><td>10</td><td>Naveen</td><td>Finance</td><td>61000</td><td>6</td><td>C</td><td>61000.00</td></tr><tr><td>11</td><td>Deepak</td><td>HR</td><td>83000</td><td>11</td><td>A</td><td>103750.00</td></tr><tr><td>12</td><td>Arjun</td><td>Engineering</td><td>54000</td><td>3</td><td>C</td><td>54000.00</td></tr><tr><td>13</td><td>Kiran</td><td>Marketing</td><td>76000</td><td>8</td><td>A</td><td>87400.00</td></tr><tr><td>14</td><td>Rohit</td><td>Finance</td><td>68000</td><td>4</td><td>B</td><td>74800.00</td></tr><tr><td>15</td><td>Pavan</td><td>HR</td><td>59000</td><td>5</td><td>B</td><td>64900.00</td></tr><tr><td>16</td><td>Srikanth</td><td>Engineering</td><td>102000</td><td>14</td><td>A</td><td>127500.00</td></tr><tr><td>17</td><td>Manoj</td><td>Finance</td><td>47000</td><td>2</td><td>C</td><td>47000.00</td></tr><tr><td>18</td><td>Varun</td><td>Marketing</td><td>52000</td><td>6</td><td>B</td><td>58240.00</td></tr><tr><td>19</td><td>Ashok</td><td>HR</td><td>74000</td><td>9</td><td>A</td><td>85100.00</td></tr><tr><td>20</td><td>Sunil</td><td>Engineering</td><td>66000</td><td>4</td><td>B</td><td>72600.00</td></tr><tr><td>21</td><td>Nikhil</td><td>Finance</td><td>86000</td><td>7</td><td>A</td><td>107500.00</td></tr><tr><td>22</td><td>Harish</td><td>Marketing</td><td>45000</td><td>1</td><td>C</td><td>45000.00</td></tr><tr><td>23</td><td>Vamsi</td><td>Engineering</td><td>79000</td><td>8</td><td>B</td><td>88480.00</td></tr><tr><td>24</td><td>Chaitanya</td><td>HR</td><td>91000</td><td>13</td><td>A</td><td>113750.00</td></tr><tr><td>25</td><td>Lokesh</td><td>Finance</td><td>58000</td><td>5</td><td>B</td><td>63800.00</td></tr></tbody></table></div>

-- %% [markdown]
-- **2.Department and Performance**
--
-- Scenario: You are tasked with giving bonuses based on the department, performance rating, and experience:
-- · For Finance department:
-- o If performance is 'A' and experience is more than 10 years, bonus is 25% of salary.
-- o Otherwise, bonus is 20%.
-- · For HR department:
-- o If performance is 'B' or experience is greater than 5 years, the bonus is 15%.
-- o Otherwise, the bonus is 10%.
-- · For other departments, the bonus is 8%.

-- %%
select *,
case 
  when department = 'Finance' then
    case
      when performance_rating = 'A' and experience > 10 then salary * 0.25
      else salary * 0.20
    end
  when department = 'HR' then
    case
      when performance_rating = 'B' or experience > 5 then salary * 0.15
      else salary * 0.10
    end
  else salary * 0.08
end as bonus
from Employeee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th
-- %% [markdown]
-- **Problem 3: Nested CASE for Employee Categorization Based on Salary, Performance, and Experience**
--
-- Scenario: Categorize employees based on their salary, performance rating, and experience:
-- · If salary is above 70,000:
-- o If performance is 'A', and experience is more than 8 years, they are labeled 'Top Performer'.
-- o If experience is less than 8 years, label them as 'Mid Performer'.
-- · If salary is between 50,000 and 70,000, they are 'Average Performer' unless their performance is 'A', in which case they are 'Rising Star'.
-- · If salary is below 50,000, they are 'Low Performer'.

-- %%
select *,
case
  when salary > 70000 then
    case
      when performance_rating = 'A' and experience > 8 then 'Top Performer'
      else 'Mid Performer'
    end
  when salary between 50000 and 70000 then
    case
      when performance_rating = 'A' then 'Rising Star'
      else 'Average Performer'
    end
  when salary < 50000 then 'Low Performer'
  else 'Uncategorized'
end as employee_category
from Employeee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>department</th><th>salary</th><th>experience</th><th>performance_rating</th><th>employee_category</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>Engineering</td><td>95000</td><td>9</td><td>A</td><td>Top Performer</td></tr><tr><td>2</td><td>Prathik</td><td>HR</td><td>55000</td><td>4</td><td>B</td><td>Average Performer</td></tr><tr><td>3</td><td>Vinay</td><td>Finance</td><td>78000</td><td>10</td><td>B</td><td>Mid Performer</td></tr><tr><td>4</td><td>Vijay</td><td>Marketing</td><td>48000</td><td>3</td><td>C</td><td>Low Performer</td></tr><tr><td>5</td><td>Anil</td><td>Engineering</td><td>88000</td><td>6</td><td>A</td><td>Mid Performer</td></tr><tr><td>6</td><td>Suresh</td><td>Finance</td><td>92000</td><td>12</td><td>A</td><td>Top Performer</td></tr><tr><td>7</td><td>Ramesh</td><td>HR</td><td>46000</td><td>2</td><td>C</td><td>Low Performer</td></tr><tr><td>8</td><td>Mahesh</td><td>Marketing</td><td>67000</td><td>7</td><td>B</td><td>Average Performer</td></tr><tr><td>9</td><td>Rajesh</td><td>Engineering</td><td>72000</td><td>5</td><td>B</td><td>Mid Performer</td></tr><tr><td>10</td><td>Naveen</td><td>Finance</td><td>61000</td><td>6</td><td>C</td><td>Average Performer</td></tr><tr><td>11</td><td>Deepak</td><td>HR</td><td>83000</td><td>11</td><td>A</td><td>Top Performer</td></tr><tr><td>12</td><td>Arjun</td><td>Engineering</td><td>54000</td><td>3</td><td>C</td><td>Average Performer</td></tr><tr><td>13</td><td>Kiran</td><td>Marketing</td><td>76000</td><td>8</td><td>A</td><td>Mid Performer</td></tr><tr><td>14</td><td>Rohit</td><td>Finance</td><td>68000</td><td>4</td><td>B</td><td>Average Performer</td></tr><tr><td>15</td><td>Pavan</td><td>HR</td><td>59000</td><td>5</td><td>B</td><td>Average Performer</td></tr><tr><td>16</td><td>Srikanth</td><td>Engineering</td><td>102000</td><td>14</td><td>A</td><td>Top Performer</td></tr><tr><td>17</td><td>Manoj</td><td>Finance</td><td>47000</td><td>2</td><td>C</td><td>Low Performer</td></tr><tr><td>18</td><td>Varun</td><td>Marketing</td><td>52000</td><td>6</td><td>B</td><td>Average Performer</td></tr><tr><td>19</td><td>Ashok</td><td>HR</td><td>74000</td><td>9</td><td>A</td><td>Top Performer</td></tr><tr><td>20</td><td>Sunil</td><td>Engineering</td><td>66000</td><td>4</td><td>B</td><td>Average Performer</td></tr><tr><td>21</td><td>Nikhil</td><td>Finance</td><td>86000</td><td>7</td><td>A</td><td>Mid Performer</td></tr><tr><td>22</td><td>Harish</td><td>Marketing</td><td>45000</td><td>1</td><td>C</td><td>Low Performer</td></tr><tr><td>23</td><td>Vamsi</td><td>Engineering</td><td>79000</td><td>8</td><td>B</td><td>Mid Performer</td></tr><tr><td>24</td><td>Chaitanya</td><td>HR</td><td>91000</td><td>13</td><td>A</td><td>Top Performer</td></tr><tr><td>25</td><td>Lokesh</td><td>Finance</td><td>58000</td><td>5</td><td>B</td><td>Average Performer</td></tr></tbody></table></div>

-- %% [markdown]
-- **4.Nested CASE for Tax Bracket Based on Salary and Experience**
--
-- Scenario: You want to determine the tax bracket of employees based on their salary and experience:
-- · If salary is above 90,000:
-- o If experience is more than 10 years, they fall into the 35% tax bracket.
-- o Otherwise, they fall into the 30% tax bracket.
-- · If salary is between 60,000 and 90,000:
-- o If experience is more than 5 years, they fall into the 25% tax bracket.
-- o Otherwise, they fall into the 20% tax bracket.
-- · For salaries below 60,000, the tax rate is 15%.

-- %%
select *,
case
  when salary > 90000 then
    case
      when experience > 10 then '35% tax bracket'
      else '30% tax bracket'
    end
  when salary between 60000 and 90000 then
    case
      when experience > 5 then '25% tax bracket'
      else '20% tax bracket'
    end
  when salary < 60000 then '15% tax bracket'
  else 'No tax bracket assigned'
end as tax_bracket
from Employeee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>department</th><th>salary</th><th>experience</th><th>performance_rating</th><th>tax_bracket</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>Engineering</td><td>95000</td><td>9</td><td>A</td><td>30% tax bracket</td></tr><tr><td>2</td><td>Prathik</td><td>HR</td><td>55000</td><td>4</td><td>B</td><td>15% tax bracket</td></tr><tr><td>3</td><td>Vinay</td><td>Finance</td><td>78000</td><td>10</td><td>B</td><td>25% tax bracket</td></tr><tr><td>4</td><td>Vijay</td><td>Marketing</td><td>48000</td><td>3</td><td>C</td><td>15% tax bracket</td></tr><tr><td>5</td><td>Anil</td><td>Engineering</td><td>88000</td><td>6</td><td>A</td><td>25% tax bracket</td></tr><tr><td>6</td><td>Suresh</td><td>Finance</td><td>92000</td><td>12</td><td>A</td><td>35% tax bracket</td></tr><tr><td>7</td><td>Ramesh</td><td>HR</td><td>46000</td><td>2</td><td>C</td><td>15% tax bracket</td></tr><tr><td>8</td><td>Mahesh</td><td>Marketing</td><td>67000</td><td>7</td><td>B</td><td>25% tax bracket</td></tr><tr><td>9</td><td>Rajesh</td><td>Engineering</td><td>72000</td><td>5</td><td>B</td><td>20% tax bracket</td></tr><tr><td>10</td><td>Naveen</td><td>Finance</td><td>61000</td><td>6</td><td>C</td><td>25% tax bracket</td></tr><tr><td>11</td><td>Deepak</td><td>HR</td><td>83000</td><td>11</td><td>A</td><td>25% tax bracket</td></tr><tr><td>12</td><td>Arjun</td><td>Engineering</td><td>54000</td><td>3</td><td>C</td><td>15% tax bracket</td></tr><tr><td>13</td><td>Kiran</td><td>Marketing</td><td>76000</td><td>8</td><td>A</td><td>25% tax bracket</td></tr><tr><td>14</td><td>Rohit</td><td>Finance</td><td>68000</td><td>4</td><td>B</td><td>20% tax bracket</td></tr><tr><td>15</td><td>Pavan</td><td>HR</td><td>59000</td><td>5</td><td>B</td><td>15% tax bracket</td></tr><tr><td>16</td><td>Srikanth</td><td>Engineering</td><td>102000</td><td>14</td><td>A</td><td>35% tax bracket</td></tr><tr><td>17</td><td>Manoj</td><td>Finance</td><td>47000</td><td>2</td><td>C</td><td>15% tax bracket</td></tr><tr><td>18</td><td>Varun</td><td>Marketing</td><td>52000</td><td>6</td><td>B</td><td>15% tax bracket</td></tr><tr><td>19</td><td>Ashok</td><td>HR</td><td>74000</td><td>9</td><td>A</td><td>25% tax bracket</td></tr><tr><td>20</td><td>Sunil</td><td>Engineering</td><td>66000</td><td>4</td><td>B</td><td>20% tax bracket</td></tr><tr><td>21</td><td>Nikhil</td><td>Finance</td><td>86000</td><td>7</td><td>A</td><td>25% tax bracket</td></tr><tr><td>22</td><td>Harish</td><td>Marketing</td><td>45000</td><td>1</td><td>C</td><td>15% tax bracket</td></tr><tr><td>23</td><td>Vamsi</td><td>Engineering</td><td>79000</td><td>8</td><td>B</td><td>25% tax bracket</td></tr><tr><td>24</td><td>Chaitanya</td><td>HR</td><td>91000</td><td>13</td><td>A</td><td>35% tax bracket</td></tr><tr><td>25</td><td>Lokesh</td><td>Finance</td><td>58000</td><td>5</td><td>B</td><td>15% tax bracket</td></tr></tbody></table></div>

-- %% [markdown]
-- **Problem 5: Nested CASE for Promotion Eligibility Based on Performance, Salary, and Experience**
--
-- Scenario: You want to determine if employees are eligible for promotion based on their performance rating, salary, and experience:
-- · If performance is 'A':
-- § If salary is more than 75,000 and experience is greater than 7 years, they are 'Eligible for Senior Role'.
-- § Otherwise, they are 'Eligible for Junior Role'.
-- · If performance is 'B':
-- § If experience is more than 5 years, they are 'Eligible for Consideration'.
-- § Otherwise, they are 'Not Eligible'.
-- · If performance is 'C', they are automatically 'Not Eligible'.

-- %%
select *,
case
  when performance_rating = 'A' then
    case
      when salary > 75000 and experience > 7 then 'Eligible for Senior Role'
      else 'Eligible for Junior Role'
    end
  when performance_rating = 'B' then
    case
      when experience > 5 then 'Eligible for Consideration'
      else 'Not Eligible'
    end
  when performance_rating = 'C' then 'Not Eligible'
  else 'No Performance Rating'
end as promotion_eligibility
from Employeee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th