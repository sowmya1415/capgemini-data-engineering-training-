-- %% [markdown]
-- ### Practise questions of REGEX

-- %%
CREATE TABLE regex_practice (
id INT,
full_text VARCHAR(200),
email VARCHAR(100),
phone VARCHAR(30),
mixed_value VARCHAR(100)
);

-- %%
INSERT INTO regex_practice VALUES
(1,'EMP001_IN_91','karthik@gmail.com','+91-9876543210','abc123xyz'),
(2,'EMP002_US_01','rahul@yahoo.com','+1-7654321098','test45done'),
(3,'EMP003_UK_44','john@outlook.com','+44-9988776655','run9fast'),
(4,'EMP004_AU_61','steve@gmail.com','+61-8899776655','go88home'),
(5,'EMP005_IN_91','arjun@company.in','+91-7788996655','data77lake'),
(6,'EMP006_US_01','meera@gmail.com','+1-9090909090','spark12sql'),
(7,'EMP007_UK_44','rohan@yahoo.com','+44-7878787878','etl999job'),
(8,'EMP008_AU_61','alice@company.au','+61-6665554443','cloud7aws'),
(9,'EMP009_IN_91','vinay@gmail.com','+91-9988776655','hdfs34node'),
(10,'EMP010_US_01','sam@outlook.com','+1-6767676767','map5reduce'),
(11,'USR11_IN','neha@gmail.com','91-8899001122','abc1'),
(12,'USR12_US','tom@yahoo.com','01-9988776655','x9'),
(13,'USR13_UK','harry@company.co.uk','44-6677889900','z88'),
(14,'USR14_AU','olivia@gmail.com','61-4455667788','q777'),
(15,'USR15_IN','ankit@company.in','91-9988001122','karthik99'),
(16,'ACC_1001_91','user1@gmail.com','+91-8877665544','etl1'),
(17,'ACC_1002_01','user2@yahoo.com','+1-2233445566','etl22'),
(18,'ACC_1003_44','user3@outlook.com','+44-3344556677','etl333'),
(19,'ACC_1004_61','user4@gmail.com','+61-5566778899','etl4444'),
(20,'ACC_1005_91','user5@company.in','+91-6677889900','etl55555'),
(21,'ORD-11-IN','a@gmail.com','91-9998887776','a1b2'),
(22,'ORD-22-US','b@yahoo.com','01-1112223334','x2y'),
(23,'ORD-33-UK','c@outlook.com','44-5556667778','m33n'),
(24,'ORD-44-AU','d@gmail.com','61-8887776665','k444'),
(25,'ORD-55-IN','e@company.in','91-4445556667','job5'),
(26,'LOG91DATA','x@gmail.com','91-9090909090','log99'),
(27,'LOG01DATA','y@yahoo.com','01-8080808080','log8'),
(28,'LOG44DATA','z@outlook.com','44-7070707070','log777'),
(29,'LOG61DATA','p@gmail.com','61-6060606060','log6666'),
(30,'LOG91DATA','q@company.in','91-5050505050','log55555'),
(31,'IND91CODE','aa@gmail.com','+91-8889990001','aa1'),
(32,'USA01CODE','bb@yahoo.com','+1-7776665554','bb22'),
(33,'UK44CODE','cc@outlook.com','+44-6665554443','cc333'),
(34,'AUS61CODE','dd@gmail.com','+61-5554443332','dd4444'),
(35,'IND91CODE','ee@company.in','+91-4443332221','ee55555'),
(36,'TEST001','test1@gmail.com','91-1111111111','t1'),
(37,'TEST002','test2@yahoo.com','01-2222222222','t22'),
(38,'TEST003','test3@outlook.com','44-3333333333','t333'),
(39,'TEST004','test4@gmail.com','61-4444444444','t4444'),
(40,'TEST005','test5@company.in','91-5555555555','t55555');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>40</td><td>40</td></tr></tbody></table></div>

-- %% [markdown]
-- 1.From the column mixed_value, extract the numeric characters that appear at the very beginning of
-- the value.
-- The extraction must stop as soon as a non-numeric character appears.

-- %%
SELECT REGEXP_SUBSTR(mixed_value, '^[0-9]+') AS extracted_number
FROM regex_practice;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>extracted_number</th></tr></thead><tbody><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- 2.From the column mixed_value, extract the numeric characters that appear at the very end of the
-- value.
-- No alphabetic or special characters should be included.

-- %%
SELECT REGEXP_SUBSTR(mixed_value, '[0-9]+$') AS extracted_value
FROM regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>extracted_value</th></tr></thead><tbody><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>88</td></tr><tr><td>777</td></tr><tr><td>99</td></tr><tr><td>1</td></tr><tr><td>22</td></tr><tr><td>333</td></tr><tr><td>4444</td></tr><tr><td>55555</td></tr><tr><td>2</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>444</td></tr><tr><td>5</td></tr><tr><td>99</td></tr><tr><td>8</td></tr><tr><td>777</td></tr><tr><td>6666</td></tr><tr><td>55555</td></tr><tr><td>1</td></tr><tr><td>22</td></tr><tr><td>333</td></tr><tr><td>4444</td></tr><tr><td>55555</td></tr><tr><td>1</td></tr><tr><td>22</td></tr><tr><td>333</td></tr><tr><td>4444</td></tr><tr><td>55555</td></tr></tbody></table></div>

-- %% [markdown]
-- 3. From the column mixed_value, extract only the first single character of the value, regardless of
-- whether it is a letter or a number.

-- %%
select REGEXP_SUBSTR(mixed_value,'^.') As extracted_value
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>extracted_value</th></tr></thead><tbody><tr><td>a</td></tr><tr><td>t</td></tr><tr><td>r</td></tr><tr><td>g</td></tr><tr><td>d</td></tr><tr><td>s</td></tr><tr><td>e</td></tr><tr><td>c</td></tr><tr><td>h</td></tr><tr><td>m</td></tr><tr><td>a</td></tr><tr><td>x</td></tr><tr><td>z</td></tr><tr><td>q</td></tr><tr><td>k</td></tr><tr><td>e</td></tr><tr><td>e</td></tr><tr><td>e</td></tr><tr><td>e</td></tr><tr><td>e</td></tr><tr><td>a</td></tr><tr><td>x</td></tr><tr><td>m</td></tr><tr><td>k</td></tr><tr><td>j</td></tr><tr><td>l</td></tr><tr><td>l</td></tr><tr><td>l</td></tr><tr><td>l</td></tr><tr><td>l</td></tr><tr><td>a</td></tr><tr><td>b</td></tr><tr><td>c</td></tr><tr><td>d</td></tr><tr><td>e</td></tr><tr><td>t</td></tr><tr><td>t</td></tr><tr><td>t</td></tr><tr><td>t</td></tr><tr><td>t</td></tr></tbody></table></div>

-- %% [markdown]
-- 4. From the column mixed_value, extract only the last single character of the value.

-- %%
select REGEXP_SUBSTR(mixed_value, '.$')as extracted_value
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>extracted_value</th></tr></thead><tbody><tr><td>z</td></tr><tr><td>e</td></tr><tr><td>t</td></tr><tr><td>e</td></tr><tr><td>e</td></tr><tr><td>l</td></tr><tr><td>b</td></tr><tr><td>s</td></tr><tr><td>e</td></tr><tr><td>e</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>8</td></tr><tr><td>7</td></tr><tr><td>9</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr><tr><td>2</td></tr><tr><td>y</td></tr><tr><td>n</td></tr><tr><td>4</td></tr><tr><td>5</td></tr><tr><td>9</td></tr><tr><td>8</td></tr><tr><td>7</td></tr><tr><td>6</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr></tbody></table></div>

-- %% [markdown]
-- 5. From the column mixed_value, extract exactly two consecutive numeric characters that appear
-- anywhere in the value.
-- Do not extract more or fewer than two digits.

-- %%
select REGEXP_SUBSTR(mixed_value, '[0-9]{2}') as extrated_value
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>extrated_value</th></tr></thead><tbody><tr><td>12</td></tr><tr><td>45</td></tr><tr><td>null</td></tr><tr><td>88</td></tr><tr><td>77</td></tr><tr><td>12</td></tr><tr><td>99</td></tr><tr><td>null</td></tr><tr><td>34</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>88</td></tr><tr><td>77</td></tr><tr><td>99</td></tr><tr><td>null</td></tr><tr><td>22</td></tr><tr><td>33</td></tr><tr><td>44</td></tr><tr><td>55</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>33</td></tr><tr><td>44</td></tr><tr><td>null</td></tr><tr><td>99</td></tr><tr><td>null</td></tr><tr><td>77</td></tr><tr><td>66</td></tr><tr><td>55</td></tr><tr><td>null</td></tr><tr><td>22</td></tr><tr><td>33</td></tr><tr><td>44</td></tr><tr><td>55</td></tr><tr><td>null</td></tr><tr><td>22</td></tr><tr><td>33</td></tr><tr><td>44</td></tr><tr><td>55</td></tr></tbody></table></div>

-- %% [markdown]
-- 6. From the column mixed_value, extract exactly one numeric character that appears anywhere in the
-- value.

-- %%
select REGEXP_SUBSTR(mixed_value, '[0-9]') as extrated_value
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>extrated_value</th></tr></thead><tbody><tr><td>1</td></tr><tr><td>4</td></tr><tr><td>9</td></tr><tr><td>8</td></tr><tr><td>7</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>7</td></tr><tr><td>3</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>8</td></tr><tr><td>7</td></tr><tr><td>9</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr><tr><td>9</td></tr><tr><td>8</td></tr><tr><td>7</td></tr><tr><td>6</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr></tbody></table></div>

-- %% [markdown]
-- 7. From the column phone, extract the country code present at the beginning of the phone number.
-- The extracted value must contain only the country code digits.

-- %%
select REGEXP_SUBSTR(phone, '^[+]?[0-9]+') as country_code
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_code</th></tr></thead><tbody><tr><td>+91</td></tr><tr><td>+1</td></tr><tr><td>+44</td></tr><tr><td>+61</td></tr><tr><td>+91</td></tr><tr><td>+1</td></tr><tr><td>+44</td></tr><tr><td>+61</td></tr><tr><td>+91</td></tr><tr><td>+1</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>+91</td></tr><tr><td>+1</td></tr><tr><td>+44</td></tr><tr><td>+61</td></tr><tr><td>+91</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>+91</td></tr><tr><td>+1</td></tr><tr><td>+44</td></tr><tr><td>+61</td></tr><tr><td>+91</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr></tbody></table></div>

-- %% [markdown]
-- Q8
-- From the column mixed_value, extract the numeric portion that is present between alphabetic
-- characters.

-- %%
SELECT 
  mixed_value,
  REGEXP_SUBSTR(mixed_value, '(?<=[A-Za-z])[0-9]+(?=[A-Za-z])') AS extracted_number
FROM regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mixed_value</th><th>extracted_number</th></tr></thead><tbody><tr><td>abc123xyz</td><td>123</td></tr><tr><td>test45done</td><td>45</td></tr><tr><td>run9fast</td><td>9</td></tr><tr><td>go88home</td><td>88</td></tr><tr><td>data77lake</td><td>77</td></tr><tr><td>spark12sql</td><td>12</td></tr><tr><td>etl999job</td><td>999</td></tr><tr><td>cloud7aws</td><td>7</td></tr><tr><td>hdfs34node</td><td>34</td></tr><tr><td>map5reduce</td><td>5</td></tr><tr><td>abc1</td><td>null</td></tr><tr><td>x9</td><td>null</td></tr><tr><td>z88</td><td>null</td></tr><tr><td>q777</td><td>null</td></tr><tr><td>karthik99</td><td>null</td></tr><tr><td>etl1</td><td>null</td></tr><tr><td>etl22</td><td>null</td></tr><tr><td>etl333</td><td>null</td></tr><tr><td>etl4444</td><td>null</td></tr><tr><td>etl55555</td><td>null</td></tr><tr><td>a1b2</td><td>1</td></tr><tr><td>x2y</td><td>2</td></tr><tr><td>m33n</td><td>33</td></tr><tr><td>k444</td><td>null</td></tr><tr><td>job5</td><td>null</td></tr><tr><td>log99</td><td>null</td></tr><tr><td>log8</td><td>null</td></tr><tr><td>log777</td><td>null</td></tr><tr><td>log6666</td><td>null</td></tr><tr><td>log55555</td><td>null</td></tr><tr><td>aa1</td><td>null</td></tr><tr><td>bb22</td><td>null</td></tr><tr><td>cc333</td><td>null</td></tr><tr><td>dd4444</td><td>null</td></tr><tr><td>ee55555</td><td>null</td></tr><tr><td>t1</td><td>null</td></tr><tr><td>t22</td><td>null</td></tr><tr><td>t333</td><td>null</td></tr><tr><td>t4444</td><td>null</td></tr><tr><td>t55555</td><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- 9. From the column email, extract the text that appears before the at-symbol.
-- The extracted value must not include the at-symbol itself.

-- %%
select REGEXP_SUBSTR(email,'[^@]+') as extracted_mail
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>extracted_mail</th></tr></thead><tbody><tr><td>karthik</td></tr><tr><td>rahul</td></tr><tr><td>john</td></tr><tr><td>steve</td></tr><tr><td>arjun</td></tr><tr><td>meera</td></tr><tr><td>rohan</td></tr><tr><td>alice</td></tr><tr><td>vinay</td></tr><tr><td>sam</td></tr><tr><td>neha</td></tr><tr><td>tom</td></tr><tr><td>harry</td></tr><tr><td>olivia</td></tr><tr><td>ankit</td></tr><tr><td>user1</td></tr><tr><td>user2</td></tr><tr><td>user3</td></tr><tr><td>user4</td></tr><tr><td>user5</td></tr><tr><td>a</td></tr><tr><td>b</td></tr><tr><td>c</td></tr><tr><td>d</td></tr><tr><td>e</td></tr><tr><td>x</td></tr><tr><td>y</td></tr><tr><td>z</td></tr><tr><td>p</td></tr><tr><td>q</td></tr><tr><td>aa</td></tr><tr><td>bb</td></tr><tr><td>cc</td></tr><tr><td>dd</td></tr><tr><td>ee</td></tr><tr><td>test1</td></tr><tr><td>test2</td></tr><tr><td>test3</td></tr><tr><td>test4</td></tr><tr><td>test5</td></tr></tbody></table></div>

-- %% [markdown]
-- 10. From the column email, extract the text that appears after the at-symbol including the domain
-- name.

-- %%
select REGEXP_SUBSTR(email,'@(.+)') as extracted_mail
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>extracted_mail</th></tr></thead><tbody><tr><td>@gmail.com</td></tr><tr><td>@yahoo.com</td></tr><tr><td>@outlook.com</td></tr><tr><td>@gmail.com</td></tr><tr><td>@company.in</td></tr><tr><td>@gmail.com</td></tr><tr><td>@yahoo.com</td></tr><tr><td>@company.au</td></tr><tr><td>@gmail.com</td></tr><tr><td>@outlook.com</td></tr><tr><td>@gmail.com</td></tr><tr><td>@yahoo.com</td></tr><tr><td>@company.co.uk</td></tr><tr><td>@gmail.com</td></tr><tr><td>@company.in</td></tr><tr><td>@gmail.com</td></tr><tr><td>@yahoo.com</td></tr><tr><td>@outlook.com</td></tr><tr><td>@gmail.com</td></tr><tr><td>@company.in</td></tr><tr><td>@gmail.com</td></tr><tr><td>@yahoo.com</td></tr><tr><td>@outlook.com</td></tr><tr><td>@gmail.com</td></tr><tr><td>@company.in</td></tr><tr><td>@gmail.com</td></tr><tr><td>@yahoo.com</td></tr><tr><td>@outlook.com</td></tr><tr><td>@gmail.com</td></tr><tr><td>@company.in</td></tr><tr><td>@gmail.com</td></tr><tr><td>@yahoo.com</td></tr><tr><td>@outlook.com</td></tr><tr><td>@gmail.com</td></tr><tr><td>@company.in</td></tr><tr><td>@gmail.com</td></tr><tr><td>@yahoo.com</td></tr><tr><td>@outlook.com</td></tr><tr><td>@gmail.com</td></tr><tr><td>@company.in</td></tr></tbody></table></div>

-- %% [markdown]
-- 11. From the column email, extract only the domain name without including the at-symbol.

-- %%
SELECT 
  email,
  REGEXP_SUBSTR(email, '(?<=@).+') AS domain
FROM regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>email</th><th>domain</th></tr></thead><tbody><tr><td>karthik@gmail.com</td><td>gmail.com</td></tr><tr><td>rahul@yahoo.com</td><td>yahoo.com</td></tr><tr><td>john@outlook.com</td><td>outlook.com</td></tr><tr><td>steve@gmail.com</td><td>gmail.com</td></tr><tr><td>arjun@company.in</td><td>company.in</td></tr><tr><td>meera@gmail.com</td><td>gmail.com</td></tr><tr><td>rohan@yahoo.com</td><td>yahoo.com</td></tr><tr><td>alice@company.au</td><td>company.au</td></tr><tr><td>vinay@gmail.com</td><td>gmail.com</td></tr><tr><td>sam@outlook.com</td><td>outlook.com</td></tr><tr><td>neha@gmail.com</td><td>gmail.com</td></tr><tr><td>tom@yahoo.com</td><td>yahoo.com</td></tr><tr><td>harry@company.co.uk</td><td>company.co.uk</td></tr><tr><td>olivia@gmail.com</td><td>gmail.com</td></tr><tr><td>ankit@company.in</td><td>company.in</td></tr><tr><td>user1@gmail.com</td><td>gmail.com</td></tr><tr><td>user2@yahoo.com</td><td>yahoo.com</td></tr><tr><td>user3@outlook.com</td><td>outlook.com</td></tr><tr><td>user4@gmail.com</td><td>gmail.com</td></tr><tr><td>user5@company.in</td><td>company.in</td></tr><tr><td>a@gmail.com</td><td>gmail.com</td></tr><tr><td>b@yahoo.com</td><td>yahoo.com</td></tr><tr><td>c@outlook.com</td><td>outlook.com</td></tr><tr><td>d@gmail.com</td><td>gmail.com</td></tr><tr><td>e@company.in</td><td>company.in</td></tr><tr><td>x@gmail.com</td><td>gmail.com</td></tr><tr><td>y@yahoo.com</td><td>yahoo.com</td></tr><tr><td>z@outlook.com</td><td>outlook.com</td></tr><tr><td>p@gmail.com</td><td>gmail.com</td></tr><tr><td>q@company.in</td><td>company.in</td></tr><tr><td>aa@gmail.com</td><td>gmail.com</td></tr><tr><td>bb@yahoo.com</td><td>yahoo.com</td></tr><tr><td>cc@outlook.com</td><td>outlook.com</td></tr><tr><td>dd@gmail.com</td><td>gmail.com</td></tr><tr><td>ee@company.in</td><td>company.in</td></tr><tr><td>test1@gmail.com</td><td>gmail.com</td></tr><tr><td>test2@yahoo.com</td><td>yahoo.com</td></tr><tr><td>test3@outlook.com</td><td>outlook.com</td></tr><tr><td>test4@gmail.com</td><td>gmail.com</td></tr><tr><td>test5@company.in</td><td>company.in</td></tr></tbody></table></div>

-- %% [markdown]
-- Q12
-- From the column email, extract only the text that appears after the last dot in the email address.

-- %%
select REGEXP_SUBSTR(email,'[^.]+$') as extracted_mail
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>extracted_mail</th></tr></thead><tbody><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>in</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>au</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>uk</td></tr><tr><td>com</td></tr><tr><td>in</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>in</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>in</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>in</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>in</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>com</td></tr><tr><td>in</td></tr></tbody></table></div>

-- %% [markdown]
-- Q13
-- From the column mixed_value, extract only alphabetic characters that appear together as a
-- continuous sequence.

-- %%
select REGEXP_SUBSTR(mixed_value,'[A-Za-z]+') as chars
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>chars</th></tr></thead><tbody><tr><td>abc</td></tr><tr><td>test</td></tr><tr><td>run</td></tr><tr><td>go</td></tr><tr><td>data</td></tr><tr><td>spark</td></tr><tr><td>etl</td></tr><tr><td>cloud</td></tr><tr><td>hdfs</td></tr><tr><td>map</td></tr><tr><td>abc</td></tr><tr><td>x</td></tr><tr><td>z</td></tr><tr><td>q</td></tr><tr><td>karthik</td></tr><tr><td>etl</td></tr><tr><td>etl</td></tr><tr><td>etl</td></tr><tr><td>etl</td></tr><tr><td>etl</td></tr><tr><td>a</td></tr><tr><td>x</td></tr><tr><td>m</td></tr><tr><td>k</td></tr><tr><td>job</td></tr><tr><td>log</td></tr><tr><td>log</td></tr><tr><td>log</td></tr><tr><td>log</td></tr><tr><td>log</td></tr><tr><td>aa</td></tr><tr><td>bb</td></tr><tr><td>cc</td></tr><tr><td>dd</td></tr><tr><td>ee</td></tr><tr><td>t</td></tr><tr><td>t</td></tr><tr><td>t</td></tr><tr><td>t</td></tr><tr><td>t</td></tr></tbody></table></div>

-- %% [markdown]
-- Q14
-- From the column mixed_value, extract only numeric characters that appear together as a continuous
-- sequence.

-- %%
select REGEXP_SUBSTR(mixed_value,'[0-9]+') as chars
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>chars</th></tr></thead><tbody><tr><td>123</td></tr><tr><td>45</td></tr><tr><td>9</td></tr><tr><td>88</td></tr><tr><td>77</td></tr><tr><td>12</td></tr><tr><td>999</td></tr><tr><td>7</td></tr><tr><td>34</td></tr><tr><td>5</td></tr><tr><td>1</td></tr><tr><td>9</td></tr><tr><td>88</td></tr><tr><td>777</td></tr><tr><td>99</td></tr><tr><td>1</td></tr><tr><td>22</td></tr><tr><td>333</td></tr><tr><td>4444</td></tr><tr><td>55555</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>33</td></tr><tr><td>444</td></tr><tr><td>5</td></tr><tr><td>99</td></tr><tr><td>8</td></tr><tr><td>777</td></tr><tr><td>6666</td></tr><tr><td>55555</td></tr><tr><td>1</td></tr><tr><td>22</td></tr><tr><td>333</td></tr><tr><td>4444</td></tr><tr><td>55555</td></tr><tr><td>1</td></tr><tr><td>22</td></tr><tr><td>333</td></tr><tr><td>4444</td></tr><tr><td>55555</td></tr></tbody></table></div>

-- %% [markdown]
-- Q15
-- From the column full_text, extract exactly the first three characters of the value.

-- %%
select REGEXP_SUBSTR(full_text,'^.{3}') as chars
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>chars</th></tr></thead><tbody><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>EMP</td></tr><tr><td>USR</td></tr><tr><td>USR</td></tr><tr><td>USR</td></tr><tr><td>USR</td></tr><tr><td>USR</td></tr><tr><td>ACC</td></tr><tr><td>ACC</td></tr><tr><td>ACC</td></tr><tr><td>ACC</td></tr><tr><td>ACC</td></tr><tr><td>ORD</td></tr><tr><td>ORD</td></tr><tr><td>ORD</td></tr><tr><td>ORD</td></tr><tr><td>ORD</td></tr><tr><td>LOG</td></tr><tr><td>LOG</td></tr><tr><td>LOG</td></tr><tr><td>LOG</td></tr><tr><td>LOG</td></tr><tr><td>IND</td></tr><tr><td>USA</td></tr><tr><td>UK4</td></tr><tr><td>AUS</td></tr><tr><td>IND</td></tr><tr><td>TES</td></tr><tr><td>TES</td></tr><tr><td>TES</td></tr><tr><td>TES</td></tr><tr><td>TES</td></tr></tbody></table></div>

-- %% [markdown]
-- Q16
-- From the column full_text, extract exactly the last two characters of the value.

-- %%
select REGEXP_SUBSTR(full_text,'.{2}$') as chars
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>chars</th></tr></thead><tbody><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>IN</td></tr><tr><td>US</td></tr><tr><td>UK</td></tr><tr><td>AU</td></tr><tr><td>IN</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>IN</td></tr><tr><td>US</td></tr><tr><td>UK</td></tr><tr><td>AU</td></tr><tr><td>IN</td></tr><tr><td>TA</td></tr><tr><td>TA</td></tr><tr><td>TA</td></tr><tr><td>TA</td></tr><tr><td>TA</td></tr><tr><td>DE</td></tr><tr><td>DE</td></tr><tr><td>DE</td></tr><tr><td>DE</td></tr><tr><td>DE</td></tr><tr><td>01</td></tr><tr><td>02</td></tr><tr><td>03</td></tr><tr><td>04</td></tr><tr><td>05</td></tr></tbody></table></div>

-- %% [markdown]
-- Q17
-- From the column full_text, extract the employee number portion that appears between the
-- alphabetic prefix and the first underscore.

-- %%
SELECT 
  full_text,
  REGEXP_EXTRACT(full_text, '^[A-Za-z]+([0-9]+)', 1) AS emp_number
FROM regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>full_text</th><th>emp_number</th></tr></thead><tbody><tr><td>EMP001_IN_91</td><td>001</td></tr><tr><td>EMP002_US_01</td><td>002</td></tr><tr><td>EMP003_UK_44</td><td>003</td></tr><tr><td>EMP004_AU_61</td><td>004</td></tr><tr><td>EMP005_IN_91</td><td>005</td></tr><tr><td>EMP006_US_01</td><td>006</td></tr><tr><td>EMP007_UK_44</td><td>007</td></tr><tr><td>EMP008_AU_61</td><td>008</td></tr><tr><td>EMP009_IN_91</td><td>009</td></tr><tr><td>EMP010_US_01</td><td>010</td></tr><tr><td>USR11_IN</td><td>11</td></tr><tr><td>USR12_US</td><td>12</td></tr><tr><td>USR13_UK</td><td>13</td></tr><tr><td>USR14_AU</td><td>14</td></tr><tr><td>USR15_IN</td><td>15</td></tr><tr><td>ACC_1001_91</td><td></td></tr><tr><td>ACC_1002_01</td><td></td></tr><tr><td>ACC_1003_44</td><td></td></tr><tr><td>ACC_1004_61</td><td></td></tr><tr><td>ACC_1005_91</td><td></td></tr><tr><td>ORD-11-IN</td><td></td></tr><tr><td>ORD-22-US</td><td></td></tr><tr><td>ORD-33-UK</td><td></td></tr><tr><td>ORD-44-AU</td><td></td></tr><tr><td>ORD-55-IN</td><td></td></tr><tr><td>LOG91DATA</td><td>91</td></tr><tr><td>LOG01DATA</td><td>01</td></tr><tr><td>LOG44DATA</td><td>44</td></tr><tr><td>LOG61DATA</td><td>61</td></tr><tr><td>LOG91DATA</td><td>91</td></tr><tr><td>IND91CODE</td><td>91</td></tr><tr><td>USA01CODE</td><td>01</td></tr><tr><td>UK44CODE</td><td>44</td></tr><tr><td>AUS61CODE</td><td>61</td></tr><tr><td>IND91CODE</td><td>91</td></tr><tr><td>TEST001</td><td>001</td></tr><tr><td>TEST002</td><td>002</td></tr><tr><td>TEST003</td><td>003</td></tr><tr><td>TEST004</td><td>004</td></tr><tr><td>TEST005</td><td>005</td></tr></tbody></table></div>

-- %% [markdown]
-- Q18
-- From the column full_text, extract the country code that appears at the end of the value.

-- %%
select REGEXP_SUBSTR(full_text,'[0-9]+$') as country_code
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_code</th></tr></thead><tbody><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>91</td></tr><tr><td>01</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>001</td></tr><tr><td>002</td></tr><tr><td>003</td></tr><tr><td>004</td></tr><tr><td>005</td></tr></tbody></table></div>

-- %% [markdown]
-- Q19
-- From the column full_text, extract the alphabetic text that appears between two underscore
-- characters.

-- %%
select REGEXP_SUBSTR(full_text,'_([A-Za-z]+)_') as alph_text
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>alph_text</th></tr></thead><tbody><tr><td>_IN_</td></tr><tr><td>_US_</td></tr><tr><td>_UK_</td></tr><tr><td>_AU_</td></tr><tr><td>_IN_</td></tr><tr><td>_US_</td></tr><tr><td>_UK_</td></tr><tr><td>_AU_</td></tr><tr><td>_IN_</td></tr><tr><td>_US_</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- Q20
-- From the column phone, extract the numeric characters that appear immediately after the plus sign.
-- The extraction must include only the digits that represent the country code.

-- %%
select REGEXP_SUBSTR(phone,'(?<=\\+)[0-9]+') as num_characters
from regex_practice
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_characters</th></tr></thead><tbody><tr><td>91</td></tr><tr><td>1</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>1</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>1</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>91</td></tr><tr><td>1</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>91</td></tr><tr><td>1</td></tr><tr><td>44</td></tr><tr><td>61</td></tr><tr><td>91</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr></tbody></table></div>
